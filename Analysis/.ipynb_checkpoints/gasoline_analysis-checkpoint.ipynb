# %%
#import libraries
import pandas as pd
import  numpy as np
import  seaborn as sns
import matplotlib.pyplot as plt
import plotly as plot

# %%
df =pd.read_excel("/Users/dersunscheinyn/Downloads/STAT 440 PROJECT/STAT440_GroupC_FinalProject/Dataset/Eight_Databases.xlsx",sheet_name="12_Year_Gasoline")

# %%
df.shape
# Out:
# (137, 5)

# %%
df.head()
# Out:
#         date  U.S. Gasoline Prices (in cents)  \
# 0 1997-01-01                            128.3
# 1 1997-02-01                            127.6
# 2 1997-03-01                            125.1
# 3 1997-04-01                            124.4
# 4 1997-05-01                            124.5
#
#    OPEC Spot Price:           $ per barrel  \
# 0                                    21.52
# 1                                    18.57
# 2                                    18.63
# 3                                    16.64
# 4                                    18.31
#
#    U.S. Finished Motor Gasoline Production  (1000 Barrels per Day)  \
# 0                                               7315
# 1                                               7330
# 2                                               7079
# 3                                               7737
# 4                                               7998
#
#    U.S. Natural Gas Wellhead Price       ($/1000 Cu.Ft.)
# 0                                               3.40
# 1                                               2.49
# 2                                               1.79
# 3                                               1.81
# 4                                               2.00

# %%
df["U.S. Gasoline Prices (in cents)"].max()
# Out:
# np.float64(381.5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137 entries, 0 to 136
# Data columns (total 5 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   date                                                             137 non-null    datetime64[ns]
#  1   U.S. Gasoline Prices (in cents)                                  137 non-null    float64
#  2   OPEC Spot Price:           $ per barrel                          137 non-null    float64
#  3   U.S. Finished Motor Gasoline Production  (1000 Barrels per Day)  137 non-null    int64
#  4   U.S. Natural Gas Wellhead Price       ($/1000 Cu.Ft.)            137 non-null    float64
# dtypes: datetime64[ns](1), float64(3), int64(1)
# memory usage: 5.5 KB

# %%
df.isna().sum()
# Out:
# date                                                               0
# U.S. Gasoline Prices (in cents)                                    0
# OPEC Spot Price:           $ per barrel                            0
# U.S. Finished Motor Gasoline Production  (1000 Barrels per Day)    0
# U.S. Natural Gas Wellhead Price       ($/1000 Cu.Ft.)              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe().T
# Out:
#                                                     count  \
# date                                                  137
# U.S. Gasoline Prices (in cents)                     137.0
# OPEC Spot Price:           $ per barrel             137.0
# U.S. Finished Motor Gasoline Production  (1000 ...  137.0
# U.S. Natural Gas Wellhead Price       ($/1000 C...  137.0
#
#                                                                              mean  \
# date                                                2002-08-31 15:45:59.124087552
# U.S. Gasoline Prices (in cents)                                        179.816058
# OPEC Spot Price:           $ per barrel                                 35.747664
# U.S. Finished Motor Gasoline Production  (1000 ...                    8444.562044
# U.S. Natural Gas Wellhead Price       ($/1000 C...                       4.469343
#
#                                                                     min  \
# date                                                1997-01-01 00:00:00
# U.S. Gasoline Prices (in cents)                                    96.2
# OPEC Spot Price:           $ per barrel                            9.56
# U.S. Finished Motor Gasoline Production  (1000 ...               7079.0
# U.S. Natural Gas Wellhead Price       ($/1000 C...                  1.7
#
#                                                                     25%  \
# date                                                1999-11-01 00:00:00
# U.S. Gasoline Prices (in cents)                                   127.6
# OPEC Spot Price:           $ per barrel                           19.21
# U.S. Finished Motor Gasoline Production  (1000 ...               8156.0
# U.S. Natural Gas Wellhead Price       ($/1000 C...                  2.6
#
#                                                                     50%  \
# date                                                2002-09-01 00:00:00
# U.S. Gasoline Prices (in cents)                                   155.6
# OPEC Spot Price:           $ per barrel                           26.64
# U.S. Finished Motor Gasoline Production  (1000 ...               8456.0
# U.S. Natural Gas Wellhead Price       ($/1000 C...                  4.4
#
#                                                                     75%  \
# date                                                2005-07-01 00:00:00
# U.S. Gasoline Prices (in cents)                                   227.5
# OPEC Spot Price:           $ per barrel                           50.29
# U.S. Finished Motor Gasoline Production  (1000 ...               8779.0
# U.S. Natural Gas Wellhead Price       ($/1000 C...                 6.06
#
#                                                                     max  \
# date                                                2008-05-01 00:00:00
# U.S. Gasoline Prices (in cents)                                   381.5
# OPEC Spot Price:           $ per barrel                          126.43
# U.S. Finished Motor Gasoline Production  (1000 ...               9429.0
# U.S. Natural Gas Wellhead Price       ($/1000 C...                10.33
#
#                                                            std
# date                                                       NaN
# U.S. Gasoline Prices (in cents)                      66.695284
# OPEC Spot Price:           $ per barrel              23.157659
# U.S. Finished Motor Gasoline Production  (1000 ...  465.434346
# U.S. Natural Gas Wellhead Price       ($/1000 C...    2.080828

# %%
df["Month"]= df["date"].dt.month_name()

# %%
df.head()
# Out:
#         date  U.S. Gasoline Prices (in cents)  \
# 0 1997-01-01                            128.3
# 1 1997-02-01                            127.6
# 2 1997-03-01                            125.1
# 3 1997-04-01                            124.4
# 4 1997-05-01                            124.5
#
#    OPEC Spot Price:           $ per barrel  \
# 0                                    21.52
# 1                                    18.57
# 2                                    18.63
# 3                                    16.64
# 4                                    18.31
#
#    U.S. Finished Motor Gasoline Production  (1000 Barrels per Day)  \
# 0                                               7315
# 1                                               7330
# 2                                               7079
# 3                                               7737
# 4                                               7998
#
#    U.S. Natural Gas Wellhead Price       ($/1000 Cu.Ft.)     Month
# 0                                               3.40       January
# 1                                               2.49      February
# 2                                               1.79         March
# 3                                               1.81         April
# 4                                               2.00           May

# %%
df["Year"]= df["date"].dt.year

# %%
df["Year"].unique()
# Out:
# array([1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007,
#        2008], dtype=int32)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137 entries, 0 to 136
# Data columns (total 7 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   date                                                             137 non-null    datetime64[ns]
#  1   U.S. Gasoline Prices (in cents)                                  137 non-null    float64
#  2   OPEC Spot Price:           $ per barrel                          137 non-null    float64
#  3   U.S. Finished Motor Gasoline Production  (1000 Barrels per Day)  137 non-null    int64
#  4   U.S. Natural Gas Wellhead Price       ($/1000 Cu.Ft.)            137 non-null    float64
#  5   Month                                                            137 non-null    object
#  6   Year                                                             137 non-null    int32
# dtypes: datetime64[ns](1), float64(3), int32(1), int64(1), object(1)
# memory usage: 7.1+ KB

# %%
# Convert gasoline price from cents to USD only
df['U.S. Gasoline Prices (in cents)'] = df['U.S. Gasoline Prices (in cents)'] / 100

# Rename all columns to remove spaces and make them clean (snake_case style)
df.rename(columns={
    'date': 'date',
    'U.S. Gasoline Prices (in cents)': 'us_gasoline_price_usd',
    'OPEC Spot Price:           $ per barrel': 'opec_spot_price_usd_per_barrel',
    'U.S. Finished Motor Gasoline Production  (1000 Barrels per Day)': 'us_gasoline_production_1000_bpd',
    'U.S. Natural Gas Wellhead Price       ($/1000 Cu.Ft.)': 'us_natural_gas_price_usd_per_1000_cuft',
    'Month': 'month',
    'Year': 'year'
}, inplace=True)

# %%
df.head(7)
# Out:
#         date  us_gasoline_price_usd  opec_spot_price_usd_per_barrel  \
# 0 1997-01-01                  1.283                           21.52
# 1 1997-02-01                  1.276                           18.57
# 2 1997-03-01                  1.251                           18.63
# 3 1997-04-01                  1.244                           16.64
# 4 1997-05-01                  1.245                           18.31
# 5 1997-06-01                  1.242                           16.69
# 6 1997-07-01                  1.220                           17.16
#
#    us_gasoline_production_1000_bpd  us_natural_gas_price_usd_per_1000_cuft  \
# 0                             7315                                    3.40
# 1                             7330                                    2.49
# 2                             7079                                    1.79
# 3                             7737                                    1.81
# 4                             7998                                    2.00
# 5                             8008                                    2.08
# 6                             7959                                    2.00
#
#       month  year
# 0   January  1997
# 1  February  1997
# 2     March  1997
# 3     April  1997
# 4       May  1997
# 5      June  1997
# 6      July  1997

# %%
df.describe().T
# Out:
#                                         count                           mean  \
# date                                      137  2002-08-31 15:45:59.124087552
# us_gasoline_price_usd                   137.0                       1.798161
# opec_spot_price_usd_per_barrel          137.0                      35.747664
# us_gasoline_production_1000_bpd         137.0                    8444.562044
# us_natural_gas_price_usd_per_1000_cuft  137.0                       4.469343
# year                                    137.0                    2002.218978
#
#                                                         min  \
# date                                    1997-01-01 00:00:00
# us_gasoline_price_usd                                 0.962
# opec_spot_price_usd_per_barrel                         9.56
# us_gasoline_production_1000_bpd                      7079.0
# us_natural_gas_price_usd_per_1000_cuft                  1.7
# year                                                 1997.0
#
#                                                         25%  \
# date                                    1999-11-01 00:00:00
# us_gasoline_price_usd                                 1.276
# opec_spot_price_usd_per_barrel                        19.21
# us_gasoline_production_1000_bpd                      8156.0
# us_natural_gas_price_usd_per_1000_cuft                  2.6
# year                                                 1999.0
#
#                                                         50%  \
# date                                    2002-09-01 00:00:00
# us_gasoline_price_usd                                 1.556
# opec_spot_price_usd_per_barrel                        26.64
# us_gasoline_production_1000_bpd                      8456.0
# us_natural_gas_price_usd_per_1000_cuft                  4.4
# year                                                 2002.0
#
#                                                         75%  \
# date                                    2005-07-01 00:00:00
# us_gasoline_price_usd                                 2.275
# opec_spot_price_usd_per_barrel                        50.29
# us_gasoline_production_1000_bpd                      8779.0
# us_natural_gas_price_usd_per_1000_cuft                 6.06
# year                                                 2005.0
#
#                                                         max         std
# date                                    2008-05-01 00:00:00         NaN
# us_gasoline_price_usd                                 3.815    0.666953
# opec_spot_price_usd_per_barrel                       126.43   23.157659
# us_gasoline_production_1000_bpd                      9429.0  465.434346
# us_natural_gas_price_usd_per_1000_cuft                10.33    2.080828
# year                                                 2008.0    3.313775

# %%
df[['us_gasoline_price_usd', 'opec_spot_price_usd_per_barrel']].corr()
# Out:
#                                 us_gasoline_price_usd  \
# us_gasoline_price_usd                        1.000000
# opec_spot_price_usd_per_barrel               0.970376
#
#                                 opec_spot_price_usd_per_barrel
# us_gasoline_price_usd                                 0.970376
# opec_spot_price_usd_per_barrel                        1.000000

# %%
plt.figure(figsize=(9,6))
sns.scatterplot(
    data=df,
    x='opec_spot_price_usd_per_barrel',
    y='us_gasoline_price_usd',
    alpha=0.7,  # makes overlap clearer
    edgecolor=None
)

# Add regression line for trend clarity
sns.regplot(
    data=df,
    x='opec_spot_price_usd_per_barrel',
    y='us_gasoline_price_usd',
    scatter=False,
    color='red',
    line_kws={'linewidth': 2}
)

# Add grid for readability
plt.grid(True, linestyle='--', alpha=0.4)

# Titles and labels (clean + professional)
plt.title('Oil Price vs Gasoline Price', fontsize=14, fontweight='bold')
plt.xlabel('OPEC Spot Price (USD per barrel)', fontsize=12)
plt.ylabel('US Gasoline Price (USD)', fontsize=12)

# Add correlation text on plot
corr_value = df['opec_spot_price_usd_per_barrel'].corr(df['us_gasoline_price_usd'])

plt.text(
    0.05, 0.95,
    f'Correlation: {corr_value:.2f}',
    transform=plt.gca().transAxes,
    fontsize=12,
    bbox=dict(facecolor='white', alpha=0.6)
)

plt.show()

# %%
df.columns
# Out:
# Index(['date', 'us_gasoline_price_usd', 'opec_spot_price_usd_per_barrel',
#        'us_gasoline_production_1000_bpd',
#        'us_natural_gas_price_usd_per_1000_cuft', 'month', 'year'],
#       dtype='object')

# %%
df['month'].value_counts()
# Out:
# month
# January      12
# February     12
# March        12
# April        12
# May          12
# June         11
# July         11
# August       11
# September    11
# October      11
# November     11
# December     11
# Name: count, dtype: int64

# %%
df.groupby("month")["us_gasoline_price_usd"].mean().sort_values(ascending=False).reset_index()
# Out:
#         month  us_gasoline_price_usd
# 0         May               1.995083
# 1       April               1.914167
# 2   September               1.840455
# 3        June               1.820273
# 4      August               1.812818
# 5        July               1.807545
# 6       March               1.802833
# 7     October               1.778091
# 8    November               1.732545
# 9    February               1.701583
# 10   December               1.689364
# 11    January               1.674333

# %%
gasoline_trend_by_year =df.groupby("year")["us_gasoline_price_usd"].mean().sort_values(ascending=False).reset_index()

# %%
gasoline_trend_by_year
# Out:
#     year  us_gasoline_price_usd
# 0   2008               3.357600
# 1   2007               2.845500
# 2   2006               2.615083
# 3   2005               2.312167
# 4   2004               1.891250
# 5   2003               1.601083
# 6   2000               1.524500
# 7   2001               1.466167
# 8   2002               1.381833
# 9   1997               1.245000
# 10  1999               1.175167
# 11  1998               1.072250

# %%
plt.figure(figsize=(10,6))
sns.lineplot(data=gasoline_trend_by_year,x="year",y="us_gasoline_price_usd")
plt.title("Trend of Gasoline Price by year")
plt.show()

# %%
#observations
